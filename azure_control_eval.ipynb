# %% [markdown]
# # Control Script

# %% [markdown]
# ## RUN TRAINING SCRIPT

# %%
from azureml.core import Workspace
from azureml.core import Experiment
from azureml.core import Environment
from azureml.core import ScriptRunConfig
from azureml.core import Dataset
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (pyOpenSSL 20.0.1 (c:\users\awnya\miniconda3\envs\ml\lib\site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyOpenSSL 20.0.1 (c:\users\awnya\miniconda3\envs\ml\lib\site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (pyOpenSSL 20.0.1 (c:\users\awnya\miniconda3\envs\ml\lib\site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (pyOpenSSL 20.0.1 (c:\users\awnya\miniconda3\envs\ml\lib\site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (pyOpenSSL 20.0.1 (c:\users\awnya\miniconda3\envs\ml\lib\site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (pyOpenSSL 20.0.1 (c:\users\awnya\miniconda3\envs\ml\lib\site-packages), Requirement.parse('pyopenssl<20.0.0')).

# %%
# set up dataset
ws = Workspace.from_config()
datastore = ws.get_default_datastore()
dataset = Dataset.File.from_files(path=(datastore, 'datasets/rgbd_dataset'))
# embedding_model = Dataset.File.from_files(path=(datastore, 'embedding_models/bit_m-r50x1_1'))

# %%
# set up experiment
experiment_name = 'evaluation'
experiment = Experiment(workspace=ws, name=experiment_name)

# %%
model_type = 'rgb-depth'
model_name = 'rgbd_model_run29'
model_weights_name = 'rgbd_model_run29_epoch3_weights.h5'

# %%
compute_name = 'gpu-compute-3dcv'

config = ScriptRunConfig(
    source_directory='./src',
    script='eval.py',
    compute_target=compute_name,
    arguments=[
        '--data_path', dataset.as_named_input('input').as_mount(),
        '--model_type', model_type,
        '--model_name', model_name,
        '--model_weights_name', model_weights_name
        #'--model_weights_path', models_azure.as_named_input('models').as_mount,
        ],
)

# %%
# # set up 3dcv environment
# env_path = '.azureml/3dcv-env.yml'
# env = Environment.from_conda_specification(
#     name='3dcv',
#     file_path=env_path
# )
# env.register(workspace=ws);

# %%
# load env
env = ws.environments['3dcv']
env.docker.enabled = True
env.docker.base_image = 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04'

# # curated tensorflow environment
# curated_env_name = 'AzureML-TensorFlow-2.2-GPU'
# env = Environment.get(workspace=ws, name=curated_env_name)
# env.docker.enabled = True
# env.docker.base_image = 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04'

# %%
config.run_config.environment = env

# %%
run = experiment.submit(config)
aml_url = run.get_portal_url()
print("Submitted to compute cluster:\n")
print(aml_url)
# Out:
# Submitted to compute cluster:
#
# https://ml.azure.com/experiments/evaluation/runs/evaluation_1614553790_bd678ec5?wsid=/subscriptions/897457a1-6166-49d3-8c12-94c50b63378f/resourcegroups/3DCV-resource-group/workspaces/3DCV

# %%
run
# Out:
# Run(Experiment: evaluation,
# Id: evaluation_1614553790_bd678ec5,
# Type: azureml.scriptrun,
# Status: Preparing)

# %%
# specify show_output to True for a verbose log
run.wait_for_completion (show_output=True)
# Out:
# 1-02-28T23:10:31.865869] Finished fetching snapshots.
# [2021-02-28T23:10:31.865884] Finished extract_project.
# [2021-02-28T23:10:31.875449] Finished fetching and extracting the control code.
# [2021-02-28T23:10:31.883351] Start run_history_prep.
# [2021-02-28T23:10:32.346699] Job preparation is complete.
# [2021-02-28T23:10:32.346740] Entering Data Context Managers in Sidecar
# [2021-02-28T23:10:32.347469] Running Sidecar prep cmd...
# [2021-02-28T23:10:32.408920] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/3dcv/azureml/evaluation_1614553790_bd678ec5/mounts/workspaceblobstore/azureml/evaluation_1614553790_bd678ec5
# [2021-02-28T23:10:32.409743] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# 2021/02/28 23:12:09 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/02/28 23:12:09 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-02-28T23:12:10.598173] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['eval.py', '--data_path', 'DatasetConsumptionConfig:input', '--model_type', 'rgb', '--model_name', 'rgb_model_run3', '--model_weights_name', 'rgb_model_run3_weights.h5'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 77
# [2021-02-28T23:12:12.336724] Entering Run History Context Manager.
# [2021-02-28T23:12:13.977393] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/3dcv/azureml/evaluation_1614553790_bd678ec5/mounts/workspaceblobstore/azureml/evaluation_1614553790_bd678ec5
# [2021-02-28T23:12:13.977568] Preparing to call script [eval.py] with arguments:['--data_path', '$input', '--model_type', 'rgb', '--model_name', 'rgb_model_run3', '--model_weights_name', 'rgb_model_run3_weights.h5']
# [2021-02-28T23:12:13.977652] After variable expansion, calling script [eval.py] with arguments:['--data_path', '/mnt/batch/tasks/shared/LS_root/jobs/3dcv/azureml/evaluation_1614553790_bd678ec5/wd/tmpf8ongfmt', '--model_type', 'rgb', '--model_name', 'rgb_model_run3', '--model_weights_name', 'rgb_model_run3_weights.h5']
#
# 2021-02-28 23:12:14.115007: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ===== INPUTS =====
# DATA PATH: /mnt/batch/tasks/shared/LS_root/jobs/3dcv/azureml/evaluation_1614553790_bd678ec5/wd/tmpf8ongfmt
# loading datasets
# 2021-02-28 23:13:04.989339: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-02-28 23:13:05.089492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0001:00:00.0 name: Tesla V100-PCIE-16GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-02-28 23:13:05.089600: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-28 23:13:05.091537: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-02-28 23:13:05.092989: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-02-28 23:13:05.093307: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-02-28 23:13:05.094897: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-02-28 23:13:05.095719: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-02-28 23:13:05.099893: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-02-28 23:13:05.101616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-02-28 23:13:05.102146: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-02-28 23:13:05.109553: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2593990000 Hz
# 2021-02-28 23:13:05.109964: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e36245e3f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-28 23:13:05.110035: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-02-28 23:13:05.242543: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e360f71620 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-02-28 23:13:05.242649: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-PCIE-16GB, Compute Capability 7.0
# 2021-02-28 23:13:05.243684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0001:00:00.0 name: Tesla V100-PCIE-16GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-02-28 23:13:05.243758: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-28 23:13:05.243821: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-02-28 23:13:05.243884: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-02-28 23:13:05.243932: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-02-28 23:13:05.243986: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-02-28 23:13:05.244031: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-02-28 23:13:05.244075: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-02-28 23:13:05.245688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-02-28 23:13:05.245754: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-28 23:13:05.690353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-28 23:13:05.690456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2021-02-28 23:13:05.690512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2021-02-28 23:13:05.692405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14763 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0001:00:00.0, compute capability: 7.0)
# done! took 49.68 seconds
# ----------------
# CLASS NAMES:
# ['apple', 'ball', 'banana', 'bell_pepper', 'binder', 'bowl', 'calculator', 'camera', 'cap', 'cell_phone', 'cereal_box', 'coffee_mug', 'comb', 'dry_battery', 'flashlight', 'food_bag', 'food_box', 'food_can', 'food_cup', 'food_jar', 'garlic', 'glue_stick', 'greens', 'hand_towel', 'instant_noodles', 'keyboard', 'kleenex', 'lemon', 'lightbulb', 'lime', 'marker', 'mushroom', 'notebook', 'onion', 'orange', 'peach', 'pear', 'pitcher', 'plate', 'pliers', 'potato', 'rubber_eraser', 'scissors', 'shampoo', 'soda_can', 'sponge', 'stapler', 'tomato', 'toothbrush', 'toothpaste', 'water_bottle']
# ----------------
# num classes:  51
# building model...
# loading weights from  models_archive/rgb_model_run3_weights.h5
# done! took 19.25 seconds
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_image (InputLayer)     [(None, 200, 200, 3)]     0
# _________________________________________________________________
# normalize (Rescaling)        (None, 200, 200, 3)       0
# _________________________________________________________________
# feat_vec_embedding (KerasLay (None, 2048)              23500352
# _________________________________________________________________
# output (Dense)               (None, 51)                104499
# =================================================================
# Total params: 23,604,851
# Trainable params: 104,499
# Non-trainable params: 23,500,352
# _________________________________________________________________
# testing against test dataset
# 2021-02-28 23:13:26.387370: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-02-28 23:13:32.610533: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
#
#  1/70 [..............................] - ETA: 0s - loss: 81.5037 - categorical_accuracy: 0.0000e+0
#  2/70 [..............................] - ETA: 3:31 - loss: 49.5143 - categorical_accuracy: 0.3057
#  3/70 [>.............................] - ETA: 4:34 - loss: 33.0991 - categorical_accuracy: 0.508
#  4/70 [>.............................] - ETA: 5:32 - loss: 24.8438 - categorical_accuracy: 0.630
#  5/70 [=>............................] - ETA: 5:51 - loss: 21.8232 - categorical_accuracy: 0.608
#  6/70 [=>............................] - ETA: 6:02 - loss: 19.5626 - categorical_accuracy: 0.5863
#  7/70 [==>...........................] - ETA: 6:05 - loss: 17.3793 - categorical_accuracy: 0.584
#  8/70 [==>...........................] - ETA: 6:08 - loss: 16.3724 - categorical_accuracy: 0.545
#  9/70 [==>...........................] - ETA: 6:01 - loss: 14.9334 - categorical_accuracy: 0.571
# 10/70 [===>..........................] - ETA: 5:53 - loss: 21.8889 - categorical_accuracy: 0.544
# 11/70 [===>..........................] - ETA: 5:47 - loss: 22.8663 - categorical_accuracy: 0.555
# 12/70 [====>.........................] - ETA: 5:47 - loss: 21.9989 - categorical_accuracy: 0.557
# 13/70 [====>.........................] - ETA: 5:41 - loss: 20.8943 - categorical_accuracy: 0.563
# 14/70 [=====>........................] - ETA: 5:42 - loss: 19.8086 - categorical_accuracy: 0.572
# 15/70 [=====>........................] - ETA: 5:37 - loss: 19.9207 - categorical_accuracy: 0.535
# 16/70 [=====>........................] - ETA: 5:32 - loss: 18.8134 - categorical_accuracy: 0.5529
# 17/70 [======>.......................] - ETA: 5:25 - loss: 19.3747 - categorical_accuracy: 0.542
# 18/70 [======>.......................] - ETA: 5:19 - loss: 19.6815 - categorical_accuracy: 0.516
# 19/70 [=======>......................] - ETA: 5:14 - loss: 19.1367 - categorical_accuracy: 0.514
# 20/70 [=======>......................] - ETA: 5:10 - loss: 18.1798 - categorical_accuracy: 0.538
# 21/70 [========>.....................] - ETA: 5:04 - loss: 17.3141 - categorical_accuracy: 0.560
# 22/70 [========>.....................] - ETA: 4:59 - loss: 16.5533 - categorical_accuracy: 0.573
# 23/70 [========>.....................] - ETA: 4:54 - loss: 15.8947 - categorical_accuracy: 0.582
# 24/70 [=========>....................] - ETA: 4:47 - loss: 15.2359 - categorical_accuracy: 0.599
# 25/70 [=========>....................] - ETA: 4:42 - loss: 14.6312 - categorical_accuracy: 0.6148
# 26/70 [==========>...................] - ETA: 4:35 - loss: 14.1617 - categorical_accuracy: 0.621
# 27/70 [==========>...................] - ETA: 4:29 - loss: 13.7761 - categorical_accuracy: 0.623
# 28/70 [===========>..................] - ETA: 4:22 - loss: 13.3303 - categorical_accuracy: 0.633
# 29/70 [===========>..................] - ETA: 4:16 - loss: 12.8707 - categorical_accuracy: 0.645
# 30/70 [===========>..................] - ETA: 4:11 - loss: 12.4417 - categorical_accuracy: 0.657
# 31/70 [============>.................] - ETA: 4:05 - loss: 12.0654 - categorical_accuracy: 0.666
# 32/70 [============>.................] - ETA: 3:59 - loss: 11.7262 - categorical_accuracy: 0.671
# 33/70 [=============>................] - ETA: 3:53 - loss: 11.4031 - categorical_accuracy: 0.676
# 34/70 [=============>................] - ETA: 3:47 - loss: 11.0688 - categorical_accuracy: 0.6851
# 35/70 [==============>...............] - ETA: 3:41 - loss: 10.7525 - categorical_accuracy: 0.694
# 36/70 [==============>...............] - ETA: 3:35 - loss: 10.4538 - categorical_accuracy: 0.702
# 37/70 [==============>...............] - ETA: 3:29 - loss: 10.1713 - categorical_accuracy: 0.710
# 38/70 [===============>..............] - ETA: 3:22 - loss: 9.9039 - categorical_accuracy: 0.718
# 39/70 [===============>..............] - ETA: 3:16 - loss: 9.6548 - categorical_accuracy: 0.72
# 40/70 [================>.............] - ETA: 3:09 - loss: 9.4136 - categorical_accuracy: 0.73
# 41/70 [================>.............] - ETA: 3:02 - loss: 9.1842 - categorical_accuracy: 0.73
# 42/70 [=================>............] - ETA: 2:56 - loss: 8.9895 - categorical_accuracy: 0.74
# 43/70 [=================>............] - ETA: 2:50 - loss: 9.3100 - categorical_accuracy: 0.73
# 44/70 [=================>............] - ETA: 2:43 - loss: 9.1331 - categorical_accuracy: 0.7338
# 45/70 [==================>...........] - ETA: 2:37 - loss: 8.9309 - categorical_accuracy: 0.73
# 46/70 [==================>...........] - ETA: 2:31 - loss: 8.7367 - categorical_accuracy: 0.74
# 47/70 [===================>..........] - ETA: 2:25 - loss: 8.5508 - categorical_accuracy: 0.75
# 48/70 [===================>..........] - ETA: 2:18 - loss: 8.3727 - categorical_accuracy: 0.75
# 49/70 [====================>.........] - ETA: 2:11 - loss: 8.2382 - categorical_accuracy: 0.75
# 50/70 [====================>.........] - ETA: 2:05 - loss: 8.1163 - categorical_accuracy: 0.76
# 51/70 [====================>.........] - ETA: 1:58 - loss: 7.9572 - categorical_accuracy: 0.76
# 52/70 [=====================>........] - ETA: 1:52 - loss: 7.8058 - categorical_accuracy: 0.76
# 53/70 [=====================>........] - ETA: 1:45 - loss: 7.6585 - categorical_accuracy: 0.77
# 54/70 [======================>.......] - ETA: 1:39 - loss: 7.5170 - categorical_accuracy: 0.7773
# 55/70 [======================>.......] - ETA: 1:33 - loss: 7.3815 - categorical_accuracy: 0.78
# 56/70 [=======================>......] - ETA: 1:27 - loss: 7.2521 - categorical_accuracy: 0.78
# 57/70 [=======================>......] - ETA: 1:21 - loss: 7.1249 - categorical_accuracy: 0.78
# 58/70 [=======================>......] - ETA: 1:15 - loss: 7.0025 - categorical_accuracy: 0.79
# 59/70 [========================>.....] - ETA: 1:09 - loss: 6.9507 - categorical_accuracy: 0.79
# 60/70 [========================>.....] - ETA: 1:03 - loss: 6.9322 - categorical_accuracy: 0.78
# 61/70 [=========================>....] - ETA: 57s - loss: 6.8343 - categorical_accuracy: 0.7906
# 62/70 [=========================>....] - ETA: 51s - loss: 6.7727 - categorical_accuracy: 0.788
# 63/70 [==========================>...] - ETA: 44s - loss: 6.6814 - categorical_accuracy: 0.790
# 64/70 [==========================>...] - ETA: 38s - loss: 6.5954 - categorical_accuracy: 0.7902
# 65/70 [==========================>...] - ETA: 32s - loss: 6.4939 - categorical_accuracy: 0.793
# 66/70 [===========================>..] - ETA: 25s - loss: 6.4061 - categorical_accuracy: 0.794
# 67/70 [===========================>..] - ETA: 19s - loss: 6.3108 - categorical_accuracy: 0.797
# 68/70 [============================>.] - ETA: 13s - loss: 6.2180 - categorical_accuracy: 0.800
# 69/70 [============================>.] - ETA: 6s - loss: 6.1292 - categorical_accuracy: 0.803
# 70/70 [==============================] - ETA: 0s - loss: 6.1105 - categorical_accuracy: 0.80
# 70/70 [==============================] - 454s 6s/step - loss: 6.1105 - categorical_accuracy: 0.8038
# done and logged!
# generating (preds, true) for dataset:
#     [1/70]
#     [2/70]
#     [3/70]
#     [4/70]
#     [5/70]
#     [6/70]
#     [7/70]
#     [8/70]
#     [9/70]
#     [10/70]
#     [11/70]
#     [12/70]
#     [13/70]
#     [14/70]
#     [15/70]
#     [16/70]
#     [17/70]
#     [18/70]
#     [19/70]
#     [20/70]
#     [21/70]
#     [22/70]
#     [23/70]
#     [24/70]
#     [25/70]
#     [26/70]
#     [27/70]
#     [28/70]
#     [29/70]
#     [30/70]
#     [31/70]
#     [32/70]
#     [33/70]
#     [34/70]
#     [35/70]
#     [36/70]
#     [37/70]
#     [38/70]
#     [39/70]
#     [40/70]
#     [41/70]
#     [42/70]
#     [43/70]
#     [44/70]
#
# Streaming azureml-logs/75_job_post-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt
# ===============================================================================================================
#
# [2021-02-28T23:23:23.170363] Entering job release
# [2021-02-28T23:23:23.914655] Starting job release
# [2021-02-28T23:23:23.915102] Logging experiment finalizing status in history service.
# [2021-02-28T23:23:23.915685] job release stage : upload_datastore starting...Starting the daemon thread to refresh tokens in background for process with pid = 976
#
# [2021-02-28T23:23:23.916009] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-02-28T23:23:23.916428] job release stage : copy_batchai_cached_logs starting...
# [2021-02-28T23:23:23.916523] job release stage : execute_job_release starting...[2021-02-28T23:23:23.916608] job release stage : copy_batchai_cached_logs completed...
#
# [2021-02-28T23:23:24.013495] Entering context manager injector.
# [2021-02-28T23:23:24.014966] job release stage : upload_datastore completed...
# [2021-02-28T23:23:24.125778] job release stage : send_run_telemetry starting...
# [2021-02-28T23:23:24.143929] job release stage : execute_job_release completed...
# [2021-02-28T23:23:24.301754] get vm size and vm region successfully.
# [2021-02-28T23:23:24.318899] get compute meta data successfully.
# [2021-02-28T23:23:24.527142] post artifact meta request successfully.
# [2021-02-28T23:23:24.561343] upload compute record artifact successfully.
# [2021-02-28T23:23:24.736617] job release stage : send_run_telemetry completed...
# [2021-02-28T23:23:24.736813] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-02-28T23:23:24.736892] Running Sidecar release cmd...
# [2021-02-28T23:23:24.746527] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/3dcv/azureml/evaluation_1614553790_bd678ec5/mounts/workspaceblobstore/azureml/evaluation_1614553790_bd678ec5
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/3dcv/azureml/evaluation_1614553790_bd678ec5/wd/tmpf8ongfmt.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/3dcv/azureml/evaluation_1614553790_bd678ec5/wd/tmpf8ongfmt.
# Exit __exit__ of DatasetContextManager
# [2021-02-28T23:23:25.516423] Removing absolute paths from host...
# [2021-02-28T23:23:25.683639] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-02-28T23:23:26.229030] Ran Sidecar release cmd.
# [2021-02-28T23:23:26.229065] Job release is complete
#
# Execution Summary
# =================
# RunId: evaluation_1614553790_bd678ec5
# Web View: https://ml.azure.com/experiments/evaluation/runs/evaluation_1614553790_bd678ec5?wsid=/subscriptions/897457a1-6166-49d3-8c12-94c50b63378f/resourcegroups/3DCV-resource-group/workspaces/3DCV
# {'runId': 'evaluation_1614553790_bd678ec5',
#  'target': 'gpu-compute-3dcv',
#  'status': 'Completed',
#  'startTimeUtc': '2021-02-28T23:10:10.072195Z',
#  'endTimeUtc': '2021-02-28T23:23:48.632738Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '3360ba15-ba60-4b0b-8c65-fb250f55a2d5',
#   'azureml.git.repository_uri': 'https://github.com/Awni00/3d-object-classification.git',
#   'mlflow.source.git.repoURL': 'https://github.com/Awni00/3d-object-classification.git',
#   'azureml.git.branch': 'main',
#   'mlflow.source.git.branch': 'main',
#   'azureml.git.commit': 'fda2b0949e99963e9017acf3d47b1087408d31ac',
#   'mlflow.source.git.commit': 'fda2b0949e99963e9017acf3d47b1087408d31ac',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'c4daad12-3ce2-4917-905c-9efddf663c27'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'eval.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data_path',
#    'DatasetConsumptionConfig:input',
#    '--model_type',
#    'rgb',
#    '--model_name',
#    'rgb_model_run3',
#    '--model_weights_name',
#    'rgb_model_run3_weights.h5'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'gpu-compute-3dcv',
#   'dataReferences': {},
#   'data': {'input': {'dataLocation': {'dataset': {'id': 'c4daad12-3ce2-4917-905c-9efddf663c27',
#       'name': None,
#       'version': None},
#      'dataPath': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': '3dcv',
#    'version': 'Autosave_2021-01-06T00:31:17Z_c58c13d0',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['defaults'],
#      'dependencies': ['python=3.7.0',
#       'pillow',
#       'qt',
#       'scipy',
#       'tensorflow-hub',
#       'numpy',
#       'pandas',
#       'matplotlib',
#       {'pip': ['tensorflow-gpu==2.3.1', 'azureml-sdk']}],
#      'name': 'azureml_b9a9050ee42fd679b069f4cd2b88582b'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': None, 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/azureml-logs/55_azureml-execution-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt?sv=2019-02-02&sr=b&sig=CINt5h3T%2BH1wPWkmjC4bi%2FyOCme5lA8caFUeoBL1fF4%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/azureml-logs/65_job_prep-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt?sv=2019-02-02&sr=b&sig=zZR1QUlbTqqKYJ5k3P7N%2FWCbxrYQEHT2MjozwBVjjgQ%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=%2BCjxT%2BM735bDa%2FBOKFQuVWoS5MkyWEPg%2FTaijVDQRe8%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/azureml-logs/75_job_post-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt?sv=2019-02-02&sr=b&sig=b8CJTDt4%2BpM7%2BRqOtdFkScAT8Ta4s7I6h%2Bfm%2FvnrdgU%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'azureml-logs/process_info.json': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=yg9O0dcxWl0MMNWfbu4uxkwgQQtVgITAa%2B0BYMAGIlU%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'azureml-logs/process_status.json': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=Rz3eAM0YpCdWnROSAbsOZ8S5YLKLsbPXxHMeq6bV%2Btc%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/77_azureml.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/77_azureml.log?sv=2019-02-02&sr=b&sig=4fLls4N7w%2B%2FsQW2NIlK3AwOehsq6yaXC%2F7famlIfVV8%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=aadUG5R6%2F%2Bw4NO55KjrlTT0GU4ljZSFFckU2ubgAf%2BI%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.0.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/dataprep/backgroundProcess_Telemetry.0.log?sv=2019-02-02&sr=b&sig=AgR0UB%2F2pjCR5KmYpDUVFuhR7%2F52S%2BuQRyX%2FYOc%2Fk1U%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=ihxL2Yu9kdvnWSqAJqKwG%2F7tDsBjSROMNJgqu7mI4xY%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=cxKPFX9Lr8DoyGGl2xybHiQ4AAIf55Ane%2B6j%2FLhTzk4%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=Euica%2FsoyAJ6i7QF%2BxLidVV%2Fw%2F0OB6PSBC16O%2FtiiIU%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/all.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/all.log?sv=2019-02-02&sr=b&sig=obl4IE9kf7tFAIXdwVOsTFZLZxkXXv0PSa4k8opmhXs%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.enter_contexts.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.enter_contexts.log?sv=2019-02-02&sr=b&sig=yXOF1ksOeDHJyumXv%2BUvtRmTYnvlWsnbP9G8nKdHTLY%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r',
#   'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.exit_contexts.log': 'https://3dcv2973724642.blob.core.windows.net/azureml/ExperimentRun/dcid.evaluation_1614553790_bd678ec5/logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.exit_contexts.log?sv=2019-02-02&sr=b&sig=bNbLQ91ZbR03aXyGAIQRL9Bmjb6j9Y0BoQ7GJEkF9bo%3D&st=2021-02-28T23%3A13%3A31Z&se=2021-03-01T07%3A23%3A31Z&sp=r'}}

# %%
run.get_file_names()
# Out:
# ['azureml-logs/55_azureml-execution-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt',
#  'azureml-logs/65_job_prep-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt',
#  'azureml-logs/70_driver_log.txt',
#  'azureml-logs/75_job_post-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt',
#  'azureml-logs/process_info.json',
#  'azureml-logs/process_status.json',
#  'logs/azureml/77_azureml.log',
#  'logs/azureml/dataprep/backgroundProcess.log',
#  'logs/azureml/dataprep/backgroundProcess_Telemetry.0.log',
#  'logs/azureml/dataprep/backgroundProcess_Telemetry.log',
#  'logs/azureml/job_prep_azureml.log',
#  'logs/azureml/job_release_azureml.log',
#  'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/all.log',
#  'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.enter_contexts.log',
#  'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.exit_contexts.log',
#  'outputs/test_pred.txt',
#  'outputs/test_true.txt']

# %%
# register model 
model = run.register_model(model_name='rgbd_model', model_path='outputs/checkpoints/epoch3_weights.h5')
print(model.name, model.id, model.version, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# ModelPathNotFoundException                Traceback (most recent call last)
# <ipython-input-13-8480058e1965> in <module>
#       1 # register model
# ----> 2 model = run.register_model(model_name='rgbd_model', model_path='outputs/checkpoints/epoch3_weights.h5')
#       3 print(model.name, model.id, model.version, sep='\t')
#
# ~\miniconda3\envs\ml\lib\site-packages\azureml\core\run.py in register_model(self, model_name, model_path, tags, properties, model_framework, model_framework_version, description, datasets, sample_input_dataset, sample_output_dataset, resource_configuration, **kwargs)
#    2096         """
#    2097         model_name_validation(model_name)
# -> 2098         return self._client.register_model(
#    2099             model_name, model_path, tags, properties, model_framework, model_framework_version,
#    2100             description=description, datasets=datasets, unpack=False, sample_input_dataset=sample_input_dataset,
#
# ~\miniconda3\envs\ml\lib\site-packages\azureml\_run_impl\run_history_facade.py in register_model(self, model_name, model_path, tags, properties, model_framework, model_framework_version, asset_id, sample_input_dataset, sample_output_dataset, resource_configuration, **kwargs)
#     438         if not cloud_file_paths:
#     439             run_files = list(self.artifacts.get_file_paths(self._origin, self._data_container_id))
# --> 440             raise ModelPathNotFoundException(
#     441                 """Could not locate the provided model_path {} in the set of files uploaded to the run: {}
#     442                 See https://aka.ms/run-logging for more details.""".format(model_path, str(run_files)))
#
# ModelPathNotFoundException: ModelPathNotFoundException:
# 	Message: Could not locate the provided model_path outputs/checkpoints/epoch3_weights.h5 in the set of files uploaded to the run: ['azureml-logs/55_azureml-execution-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt', 'azureml-logs/65_job_prep-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt', 'azureml-logs/70_driver_log.txt', 'azureml-logs/75_job_post-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt', 'azureml-logs/process_info.json', 'azureml-logs/process_status.json', 'logs/azureml/77_azureml.log', 'logs/azureml/dataprep/backgroundProcess.log', 'logs/azureml/dataprep/backgroundProcess_Telemetry.0.log', 'logs/azureml/dataprep/backgroundProcess_Telemetry.log', 'logs/azureml/job_prep_azureml.log', 'logs/azureml/job_release_azureml.log', 'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/all.log', 'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.enter_contexts.log', 'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.exit_contexts.log', 'outputs/test_pred.txt', 'outputs/test_true.txt']
#                 See https://aka.ms/run-logging for more details.
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Could not locate the provided model_path outputs/checkpoints/epoch3_weights.h5 in the set of files uploaded to the run: ['azureml-logs/55_azureml-execution-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt', 'azureml-logs/65_job_prep-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt', 'azureml-logs/70_driver_log.txt', 'azureml-logs/75_job_post-tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d.txt', 'azureml-logs/process_info.json', 'azureml-logs/process_status.json', 'logs/azureml/77_azureml.log', 'logs/azureml/dataprep/backgroundProcess.log', 'logs/azureml/dataprep/backgroundProcess_Telemetry.0.log', 'logs/azureml/dataprep/backgroundProcess_Telemetry.log', 'logs/azureml/job_prep_azureml.log', 'logs/azureml/job_release_azureml.log', 'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/all.log', 'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.enter_contexts.log', 'logs/azureml/sidecar/tvmps_12eb0df245e358fa6ee016512c90fdd2b1f557780eae3d7502072049e0bd2b15_d/task.exit_contexts.log', 'outputs/test_pred.txt', 'outputs/test_true.txt']\n                See https://aka.ms/run-logging for more details."
#     }
# }
